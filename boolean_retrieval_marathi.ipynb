# %% [markdown]
# ### Data Preprocessing

# %%
import os
import shutil

root_dir = "/home/achal/Downloads/marathi/mr.doc.2010/Marathi-Data"
dest_dir = "/home/achal/Downloads/marathi/mr.doc.2010/Marathi-Data/documents"

os.makedirs(dest_dir, exist_ok=True)

for subdir, _, files in os.walk(root_dir, topdown=False):
    for file in files:
        if file.endswith(".cms.txt") or file.endswith(".htm.txt") or file.endswith(".htm.1.txt") or file.endswith(".htm.2.txt"):
            file_path = os.path.join(subdir, file)
            shutil.move(file_path, os.path.join(dest_dir, file))
for subdir, _, _ in os.walk(root_dir, topdown=False):
    if not os.listdir(subdir):
        os.rmdir(subdir)

print("All .utf8 files moved successfully, and empty folders deleted!")
# Out:
# All .utf8 files moved successfully, and empty folders deleted!

# %%
import os
import re

input_dir = "/home/achal/Downloads/marathi/documents"
tags_pattern = r'</?(doc|text)>|<docno>.*?</docno>'
datetime_pattern = r'\[\s*[A-Za-z]+,\s+[A-Za-z]+\s+\d{1,2},\s+\d{4}\s+\d{2}:\d{2}:\d{2}\s+[apAP][mM]\s*\]'
punctuation_pattern = r'[।!?.,:;\'"()\[\]{}॥]+'

for filename in os.listdir(input_dir):
    if filename.endswith(".cms.txt") or filename.endswith(".htm.txt") or filename.endswith(".htm.1.txt") or filename.endswith(".htm.2.txt"):
        file_path = os.path.join(input_dir, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            content = re.sub(tags_pattern, '', content)
            content = re.sub(datetime_pattern, '', content)
            content = re.sub(punctuation_pattern, '', content)
            content = content.lower()
            content = ' '.join(content.split())
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(content)

print("All documents have been cleaned in-place!")
# Out:
# All documents have been cleaned in-place!

# %% [markdown]
# ### Converting to Pandas Dataframe

# %%
import pandas as pd
import os

input_dir = "/home/achal/Downloads/marathi/documents"
data = []

for filename in os.listdir(input_dir):
    if filename.endswith(".cms.txt")  or filename.endswith(".htm.txt") or filename.endswith(".htm.1.txt") or filename.endswith(".htm.2.txt"):
        file_path = os.path.join(input_dir, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
        data.append({"filename": filename, "content": content})

df = pd.DataFrame(data)
print(df.head())
df.to_csv("marathi_documents.csv", index=False, encoding="utf-8")

# %%
import pandas as pd

file_path = '/kaggle/input/marathi-documents/marathi_documents.csv'
df = pd.read_csv(file_path)
df
# Out:
#                             filename  \
# 0                    2132377.cms.txt
# 1                    1802816.cms.txt
# 2                    1006707.cms.txt
# 3                     963568.cms.txt
# 4           Mumbai2A1752ACAA.htm.txt
# ...                              ...
# 99270                1017374.cms.txt
# 99271  MaharashtraA294AEB2F0.htm.txt
# 99272       Mumbai82A9804E43.htm.txt
# 99273      Solapur42BC2D8C97.htm.txt
# 99274                1367653.cms.txt
#
#                                                  content
# 0      महाराष्ट्र नागपूर विधानभवनासमोर वृद्धाची आत्मह...
# 1      महामुंबई दिव्यांनी उजळायची दीप अमावास्या म टा ...
# 2      अर्थव्यवहार आयओसी भागभांडवल विकण्याचा प्रस्ताव...
# 3      संवाद लॉटरी का लागत नाही तुम्हाला कधी लॉटरी ला...
# 4      दरवर्षी तंबाखू घेतो ५० लाख व्यक्तींचा बळी मुंब...
# ...                                                  ...
# 99270  महामुंबई मुंबई टाइम्स वरळीत सायकल स्पर्धा मुंब...
# 99271  अशोकच्या कर्मचाऱ्यांना वेतनवाढ लागू होणार - मु...
# 99272  भाऊ दाजी संग्रहालयप्रकरणी महापौरांचे चौकशीचे आ...
# 99273  अंदाजपत्रक दुरुस्ती प्रस्तावावर महापालिकेची शु...
# 99274  टॉप गिअर कारसाठी बारमाही संकल्प नव्या वर्षाच्य...
#
# [99275 rows x 2 columns]

# %% [markdown]
# ### Stopword Removal

# %% [markdown]
# List of stopwords in marathi taken from : [Github](https://github.com/stopwords-iso/stopwords-mr/blob/master/stopwords-mr.json)

# %%
stop_words_marathi = ["अधिक","अनेक","अशी","असलयाचे","असलेल्या","असा","असून","असे","आज","आणि","आता","आपल्या","आला","आली","आले","आहे","आहेत","एक","एका","कमी","करणयात","करून","का","काम","काय","काही","किवा","की","केला","केली","केले","कोटी","गेल्या","घेऊन","जात","झाला","झाली","झाले","झालेल्या","टा","डॉ","तर","तरी","तसेच","ता","ती","तीन","ते","तो","त्या","त्याचा","त्याची","त्याच्या","त्याना","त्यानी","त्यामुळे","त्री","दिली","दोन","न","नाही","निर्ण्य","पण","पम","परयतन","पाटील","म","मात्र","माहिती","मी","मुबी","म्हणजे","म्हणाले","म्हणून","या","याचा","याची","याच्या","याना","यानी","येणार","येत","येथील","येथे","लाख","व","व्यकत","सर्व","सागित्ले","सुरू","हजार","हा","ही","हे","होणार","होत","होता","होती","होते"]

def remove_stopwords(text):
    if not isinstance(text, str):
        return text
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words_marathi]
    return " ".join(filtered_words)

df["content"] = df["content"].apply(remove_stopwords)
df
# Out:
#                             filename  \
# 0                    2132377.cms.txt
# 1                    1802816.cms.txt
# 2                    1006707.cms.txt
# 3                     963568.cms.txt
# 4           Mumbai2A1752ACAA.htm.txt
# ...                              ...
# 99270                1017374.cms.txt
# 99271  MaharashtraA294AEB2F0.htm.txt
# 99272       Mumbai82A9804E43.htm.txt
# 99273      Solapur42BC2D8C97.htm.txt
# 99274                1367653.cms.txt
#
#                                                  content
# 0      महाराष्ट्र नागपूर विधानभवनासमोर वृद्धाची आत्मह...
# 1      महामुंबई दिव्यांनी उजळायची दीप अमावास्या प्रति...
# 2      अर्थव्यवहार आयओसी भागभांडवल विकण्याचा प्रस्ताव...
# 3      संवाद लॉटरी लागत तुम्हाला कधी लॉटरी लागल्याचे ...
# 4      दरवर्षी तंबाखू घेतो ५० व्यक्तींचा बळी मुंबई ३०...
# ...                                                  ...
# 99270  महामुंबई मुंबई टाइम्स वरळीत सायकल स्पर्धा मुंब...
# 99271  अशोकच्या कर्मचाऱ्यांना वेतनवाढ लागू - मुरकुटे ...
# 99272  भाऊ दाजी संग्रहालयप्रकरणी महापौरांचे चौकशीचे आ...
# 99273  अंदाजपत्रक दुरुस्ती प्रस्तावावर महापालिकेची शु...
# 99274  टॉप गिअर कारसाठी बारमाही संकल्प नव्या वर्षाच्य...
#
# [99275 rows x 2 columns]

# %% [markdown]
# ### Stemming

# %%
def marathi_porter_stemmer(word):
    """
    Marathi-specific Porter stemmer to reduce words to their root form by removing suffixes.

    Args:
    - word: The input Marathi word (string).

    Returns:
    - stemmed_word: The root form of the input word (string).
    """
    # Define suffixes for Marathi
    suffixes = {
        1: [u"ा", u"े", u"ी", u"ु", u"ू", u"ो", u"े"],
        2: [u"कर", u"ने", u"नी", u"ना", u"ला", u"ता", u"ते", u"ले", u"वे", u"शी"],
        3: [u"ासाठी", u"ाकर", u"ाने", u"ाया", u"तील", u"तील"],
        4: [u"तांचा", u"तासह", u"बरोबर", u"च्या"],
        5: [u"संपर्कात", u"वाढवलेला"],
    }
    # Iterate over suffixes from longest to shortest
    for L in sorted(suffixes.keys(), reverse=True):
        if len(word) > L + 1:  # Ensure word is long enough
            for suffix in suffixes[L]:
                if word.endswith(suffix):
                    return word[:-L]  # Remove suffix and return root
    return word  # Return original word if no suffix matches


def apply_stemming(text):
    if not isinstance(text, str):
        return text
    words = text.split()
    stemmed_words = [marathi_porter_stemmer(word) for word in words]
    return " ".join(stemmed_words)

df["content"] = df["content"].apply(apply_stemming)
df
# Out:
#                             filename  \
# 0                    2132377.cms.txt
# 1                    1802816.cms.txt
# 2                    1006707.cms.txt
# 3                     963568.cms.txt
# 4           Mumbai2A1752ACAA.htm.txt
# ...                              ...
# 99270                1017374.cms.txt
# 99271  MaharashtraA294AEB2F0.htm.txt
# 99272       Mumbai82A9804E43.htm.txt
# 99273      Solapur42BC2D8C97.htm.txt
# 99274                1367653.cms.txt
#
#                                                  content
# 0      महाराष्ट्र नागपूर विधानभवनासमोर वृद्धाच आत्महत...
# 1      महामुंबई दिव्यां उजळायच दीप अमावास्य प्रतिनिध ...
# 2      अर्थव्यवहार आयओस भागभांडवल विकण्याच प्रस्ताव व...
# 3      संवाद लॉटर लागत तुम्हा कध लॉटर लागल्याच स्वप्न...
# 4      दरवर्ष तंबाख घेत ५० व्यक्तींच बळ मुंबई ३० - तं...
# ...                                                  ...
# 99270  महामुंबई मुंबई टाइम्स वरळीत सायकल स्पर्ध मुंबई...
# 99271  अशोक कर्मचाऱ्यां वेतनवाढ लाग - मुरकुट श्रीरामप...
# 99272  भाऊ दाज संग्रहालयप्रकरण महापौरांच चौकशीच आदेश ...
# 99273  अंदाजपत्रक दुरुस्त प्रस्तावावर महापालिकेच शुक्...
# 99274  टॉप गिअर कारसाठ बारमाह संकल्प नव्य वर्षा सुरुव...
#
# [99275 rows x 2 columns]

# %% [markdown]
# ### Calculating TF (Term-Frequency) and DF (Document-Frequency)

# %%
from collections import defaultdict
import pandas as pd

index = defaultdict(lambda: defaultdict(int)) # inverted indexing

for _, row in df.iterrows(): # Building the posting list
    filename = row["filename"]
    words = row["content"].split()
    for word in words:
        index[word][filename] += 1  # Increase term frequency (TF) for the word in this document

index_data = []
for term, postings in index.items():
    doc_frequency = len(postings)  # Number of documents containing this term (DF)
    for doc, tf in postings.items():
        index_data.append((term, doc, tf, doc_frequency))

index_df = pd.DataFrame(index_data, columns=["Term", "Document", "Term Frequency", "Document Frequency"])
index_df
# Out:
#                    Term                  Document  Term Frequency  \
# 0            महाराष्ट्र           2132377.cms.txt               1
# 1            महाराष्ट्र            869185.cms.txt               1
# 2            महाराष्ट्र            857578.cms.txt               2
# 3            महाराष्ट्र           1236199.cms.txt               1
# 4            महाराष्ट्र           1933774.cms.txt               1
# ...                 ...                       ...             ...
# 16112203    इन्टॅक्‍टकड  Mumbai82A9804E43.htm.txt               1
# 16112204        स्वीकरा  Mumbai82A9804E43.htm.txt               1
# 16112205     संकल्पांचं           1367653.cms.txt               1
# 16112206   विण्डस्क्रीन           1367653.cms.txt               1
# 16112207  ट्रान्समिशनचं           1367653.cms.txt               1
#
#           Document Frequency
# 0                      18542
# 1                      18542
# 2                      18542
# 3                      18542
# 4                      18542
# ...                      ...
# 16112203                   1
# 16112204                   1
# 16112205                   1
# 16112206                   1
# 16112207                   1
#
# [16112208 rows x 4 columns]

# %%
index_df.describe()
# Out:
#        Term Frequency  Document Frequency
# count    1.611221e+07        1.611221e+07
# mean     1.332784e+00        4.102868e+03
# std      1.003118e+00        7.821512e+03
# min      1.000000e+00        1.000000e+00
# 25%      1.000000e+00        1.590000e+02
# 50%      1.000000e+00        1.138000e+03
# 75%      1.000000e+00        4.722000e+03
# max      1.530000e+02        6.831500e+04

# %% [markdown]
# ### Printing Posting List for a term

# %%
def print_posting_list(term):
    if term in index:
        print(f"Posting List for '{term}':")
        for doc, tf in index[term].items():
            df = index[term][doc]
            print(f"Document: {doc}, Term Frequency: {tf}, Document Frequency: {df}")
    else:
        print(f"Term '{term}' not found in the index.")

print_posting_list("फुलपाखरासारख") # ex
# Out:
# Posting List for 'फुलपाखरासारख':
# Document: 2045406.cms.txt, Term Frequency: 1, Document Frequency: 1
# Document: 1628829.cms.txt, Term Frequency: 1, Document Frequency: 1
# Document: 1908563.cms.txt, Term Frequency: 1, Document Frequency: 1
# Document: 2215300.cms.txt, Term Frequency: 1, Document Frequency: 1
# Document: 1890723.cms.txt, Term Frequency: 1, Document Frequency: 1

# %% [markdown]
# ## Boolean Retrieval

# %% [markdown]
# ### AND Query

# %%
# AND Query: Retrieves documents that contain all specified terms
def and_query(*terms):
    result = set(index.get(terms[0], {}).keys())
    for term in terms[1:]:
        result &= set(index.get(term, {}).keys())
    return result
    
print("AND Query (फुलपाखरासारख AND स्वप्नं):", and_query("फुलपाखरासारख", "स्वप्नं"))
# Out:
# AND Query (फुलपाखरासारख AND स्वप्नं): {'2045406.cms.txt'}

# %% [markdown]
# ### OR Query

# %%
# OR Query: Retrieves documents that contain either of the terms
def or_query(*terms):
    result = set()
    for term in terms:
        result |= set(index.get(term, {}).keys())
    return result

print("OR Query (फुलपाखरासारख OR स्वप्नं):", or_query("फुलपाखरासारख", "स्वप्नं"))
# Out:
# OR Query (फुलपाखरासारख OR स्वप्नं): {'1168532.cms.txt', '1093273.cms.txt', '1789525.cms.txt', '1529202.cms.txt', '1490744.cms.txt', '1153002.cms.txt', '1186453.cms.txt', '1135119.cms.txt', '1033615.cms.txt', '1209808.cms.txt', '917829.cms.txt', '1172198.cms.txt', '1224968.cms.txt', '858720.cms.txt', '1379903.cms.txt', '1319177.cms.txt', '1170828.cms.txt', '878965.cms.txt', '873237.cms.txt', '978406.cms.txt', '1539825.cms.txt', '1998351.cms.txt', '955204.cms.txt', '1313045.cms.txt', '1285564.cms.txt', '1372304.cms.txt', '1353895.cms.txt', '1238366.cms.txt', '1371328.cms.txt', '1102158.cms.txt', '957414.cms.txt', '1410664.cms.txt', 'Nagpur6F5D4D833D.htm.txt', '1281458.cms.txt', '1908563.cms.txt', 'MuktapithD334B5C234.htm.txt', '1081167.cms.txt', '1300405.cms.txt', '958667.cms.txt', '1289742.cms.txt', '1610764.cms.txt', '923434.cms.txt', '1514546.cms.txt', '1019641.cms.txt', '928253.cms.txt', '1139301.cms.txt', '1890723.cms.txt', '1136049.cms.txt', '462542.cms.txt', '1121499.cms.txt', '1236918.cms.txt', '1339135.cms.txt', '996173.cms.txt', '1113501.cms.txt', '1006491.cms.txt', '1193693.cms.txt', 'Saptarang725DF55B02.htm.txt', '2053163.cms.txt', '1326574.cms.txt', '1187711.cms.txt', 'MuktapithD77865605B.htm.txt', '1431014.cms.txt', '1256812.cms.txt', '370442.cms.txt', '896129.cms.txt', '1490737.cms.txt', '457458.cms.txt', '1188225.cms.txt', '656030.cms.txt', '1510236.cms.txt', '1246985.cms.txt', '972533.cms.txt', '1464014.cms.txt', '1286479.cms.txt', '1678886.cms.txt', '1379911.cms.txt', '895965.cms.txt', '842545.cms.txt', '1240601.cms.txt', '886846.cms.txt', '1641387.cms.txt', '1172330.cms.txt', '2018678.cms.txt', '1518930.cms.txt', '1537258.cms.txt', '1206395.cms.txt', '1354340.cms.txt', '886623.cms.txt', '1226900.cms.txt', '902586.cms.txt', '1281335.cms.txt', '938616.cms.txt', '996376.cms.txt', '1510240.cms.txt', '896701.cms.txt', '400317.cms.txt', '1285555.cms.txt', '2207202.cms.txt', '2025997.cms.txt', '1350105.cms.txt', '1212311.cms.txt', '1262882.cms.txt', '298765.cms.txt', '1026207.cms.txt', '1438141.cms.txt', '2011446.cms.txt', '1596832.cms.txt', '1396861.cms.txt', '1717286.cms.txt', 'SaptarangFF15D17A49.htm.txt', '951919.cms.txt', '1193721.cms.txt', '871564.cms.txt', '914818.cms.txt', '1430804.cms.txt', '1233390.cms.txt', '977382.cms.txt', '1414804.cms.txt', '917852.cms.txt', '2026501.cms.txt', 'Sports2A040FA6D9.htm.txt', '879679.cms.txt', '1693881.cms.txt', '1261476.cms.txt', '2014954.cms.txt', '853142.cms.txt', '872109.cms.txt', '929820.cms.txt', '1110297.cms.txt', '1253555.cms.txt', '873289.cms.txt', '940080.cms.txt', '462353.cms.txt', '1144158.cms.txt', '1767357.cms.txt', '1353783.cms.txt', '1186093.cms.txt', '1111953.cms.txt', '1400808.cms.txt', '1296216.cms.txt', '880347.cms.txt', '1521513.cms.txt', '925685.cms.txt', '1292666.cms.txt', '1984361.cms.txt', '1694128.cms.txt', '1937285.cms.txt', 'SAPTARANG6BA12A9265.htm.txt', '1024017.cms.txt', '1243059.cms.txt', '1049619.cms.txt', '2205757.cms.txt', '930908.cms.txt', '1180898.cms.txt', '1134121.cms.txt', '1179141.cms.txt', '1309019.cms.txt', 'Muktapith1F51B4F08B.htm.txt', '1218315.cms.txt', '1200640.cms.txt', '1367646.cms.txt', '917832.cms.txt', '1213530.cms.txt', '1783597.cms.txt', '2215300.cms.txt', '917858.cms.txt', '1012879.cms.txt', '1200631.cms.txt', '1174402.cms.txt', 'DelightEFDC58BD64.htm.txt', '1371324.cms.txt', '1191369.cms.txt', '1301672.cms.txt', '1150839.cms.txt', '1357445.cms.txt', '1160164.cms.txt', '2215790.cms.txt', '1482798.cms.txt', '1951031.cms.txt', '1973942.cms.txt', '1372012.cms.txt', '1017444.cms.txt', '1025752.cms.txt', '1347115.cms.txt', '977848.cms.txt', '1193101.cms.txt', '1257690.cms.txt', '1908297.cms.txt', '1335765.cms.txt', 'Muktapith2F4215C1F2.htm.txt', '895952.cms.txt', '1458275.cms.txt', '2045406.cms.txt', '1458396.cms.txt', '1313037.cms.txt', '921342.cms.txt', '1428491.cms.txt', '842821.cms.txt', '854544.cms.txt', '1158610.cms.txt', '1448097.cms.txt', '2216005.cms.txt', '1152349.cms.txt', '1458303.cms.txt', '2129778.cms.txt', '9547 ...

# %% [markdown]
# ### NOT query

# %%
# NOT Query: Retrieves documents that do not contain the specified term
def not_query(term):
    all_docs = set(df["filename"].tolist())
    term_docs = set(index.get(term, {}).keys())  # Documents containing the term
    return all_docs - term_docs # union - given

print("NOT Query (NOT महाराष्ट्र):", not_query("महाराष्ट्र"))
# Out:
# NOT Query (NOT महाराष्ट्र): {'1294003.cms.txt', '1389887.cms.txt', 'MaharashtraDAC66E1549.htm.txt', 'Kolhapur57388CC845.htm.txt', '1294924.cms.txt', '905101.cms.txt', '1475505.cms.txt', '1260197.cms.txt', 'Goa9D2EE4797D.htm.txt', 'Maharashtra3E359D31F4.htm.txt', '1679104.cms.txt', 'Maharashtra72D89C74B8.htm.txt', 'TAJYABATMYASPECIALNEWSINTERNATIONAL2F0153D6C0.htm.txt', 'Goa1E783F0E42.htm.txt', '658472.cms.txt', '880235.cms.txt', '952309.cms.txt', '1172485.cms.txt', '863441.cms.txt', 'Sports6F8848D528.htm.txt', '1395113.cms.txt', '1031557.cms.txt', 'National2290CB58F2.htm.txt', '2007761.cms.txt', '1001381.cms.txt', 'PuneC8AC8AA915.htm.txt', '1702306.cms.txt', '345641.cms.txt', 'Goa95B7EAA53E.htm.txt', '1164412.cms.txt', 'Nasik16651ECF45.htm.txt', '888058.cms.txt', 'Nasik24A12C1063.htm.txt', 'AurangabadC39A550042.htm.txt', 'Solapur19CFA58EC5.htm.txt', 'Arthvishwa7D3E0D0AA5.htm.txt', '1324543.cms.txt', '1186116.cms.txt', '1859384.cms.txt', '1420403.cms.txt', '1173202.cms.txt', '1511590.cms.txt', '2153519.cms.txt', '444387.cms.txt', '1519532.cms.txt', 'Sakalvishesh6EC34DF836.htm.txt', '1773441.cms.txt', '1661552.cms.txt', '1698439.cms.txt', '1719478.cms.txt', '1652271.cms.txt', '866980.cms.txt', '905730.cms.txt', 'National3522B088DA.htm.txt', 'Pune849E49F000.htm.txt', 'KolhapurFF9AF68E1D.htm.txt', '1112074.cms.txt', '1702718.cms.txt', '1318019.cms.txt', 'MumbaiAA9C6EF853.htm.txt', '1767345.cms.txt', 'National51C7EF54B7.htm.txt', '1386323.cms.txt', 'PuneED9F1E5231.htm.txt', 'Jalgaon461B25E89D.htm.txt', '1408746.cms.txt', 'Mumbai60FF9B7829.htm.txt', '1477901.cms.txt', 'Solapur34AC506491.htm.txt', '1316676.cms.txt', 'Aurangabad33C3539AA6.htm.txt', 'AurangabadDE5F0A1885.htm.txt', 'JalgaonE5C2CC469D.htm.txt', '1477579.cms.txt', '2023359.cms.txt', '1398565.cms.txt', 'Mumbai90EBB6C9CF.htm.txt', 'Mumbai1C4DE03264.htm.txt', 'Aurangabad382D8D2393.htm.txt', '1898728.cms.txt', 'Pune8E698C953B.htm.txt', 'Kolhapur177A5DD0F1.htm.txt', 'SataraC03CF1AD48.htm.txt', 'International07AE2EC885.htm.txt', 'Maharashtra3CB30AD530.htm.txt', '986454.cms.txt', '1951263.cms.txt', '1142141.cms.txt', 'Muktapith2DBB31309A.htm.txt', 'Goa9FFA01D619.htm.txt', '373567.cms.txt', 'Maharashtra3F3DDFBC8A.htm.txt', 'GoaDFB6DC338E.htm.txt', 'Nagpur8B570A265B.htm.txt', 'SakalvisheshD2ACC0FD54.htm.txt', '1688790.cms.txt', 'National2E418288AA.htm.txt', '1275001.cms.txt', '992033.cms.txt', 'PuneD13F9B108F.htm.txt', '1844695.cms.txt', 'Kolhapur9E602BC77F.htm.txt', '1758250.cms.txt', '887095.cms.txt', 'Pune4E123C41DD.htm.txt', '1434741.cms.txt', '1221056.cms.txt', '173336.cms.txt', '1281389.cms.txt', 'Nasik8ADA587D44.htm.txt', '1629221.cms.txt', 'Family_Doctor7B544E5623.htm.txt', '1206402.cms.txt', '1036169.cms.txt', 'Maharashtra6EAB43A660.htm.txt', '1611942.cms.txt', '956411.cms.txt', '358045.cms.txt', 'Jalgaon3D43485A4A.htm.txt', '287480.cms.txt', '1158900.cms.txt', '1221508.cms.txt', 'MaharashtraF9133C789E.htm.txt', '1397084.cms.txt', '1116152.cms.txt', 'Aurangabad6565B34B4F.htm.txt', 'National2AFA0C163A.htm.txt', '1401870.cms.txt', '1844688.cms.txt', 'Jalgaon3D02DBC768.htm.txt', 'Mumbai41AD1F8176.htm.txt', 'Pune56D138B893.htm.txt', '1015276.cms.txt', '1469990.cms.txt', 'Pune5BFD3BBE1B.htm.txt', 'Solapur028604121B.htm.txt', '418806.cms.txt', 'Satara9F7EF35930.htm.txt', '1383697.cms.txt', '1850060.cms.txt', '1393225.cms.txt', 'PuneE34F1C71D3.htm.txt', '984380.cms.txt', 'Mumbai420AE091ED.htm.txt', '1253944.cms.txt', '1043913.cms.txt', 'Satara5FB8B5A517.htm.txt', '861528.cms.txt', 'SataraC64535A1AD.htm.txt', '2169871.cms.txt', '879678.cms.txt', 'Goa3B9E90B0FA.htm.txt', 'SakalvisheshA4C62CCBDF.htm.txt', '1636897.cms.txt', 'Sports4A67584FA9.htm.txt', '1584740.cms.txt', '1128353.cms.txt', '1257646.cms.txt', '909483.cms.txt', '1105624.cms.txt', '1413462.cms.txt', '1375542.cms.txt', 'NagpurB3AF3E0C50.htm.txt', 'Nasik74E04C5990.htm.txt', '933304.cms.txt', '445585.cms.txt', '960191.cms.txt', 'Sakalvishesh22C2477D56.htm.txt', 'Pune2050EF0D8D.htm.txt', 'AurangabadFAE4284D73.htm.txt', 'So ...
